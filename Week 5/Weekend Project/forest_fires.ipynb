# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np
from IPython.display import Image

# %%
data = pd.read_csv('C:/Users/RedneckRandy/Downloads/forestfires.csv')
data['intercept'] = 1

# %%
plt.scatter(data['FFMC'], data['temp'])
plt.xlabel('FFMC(Fine Fuel Moisture Code)')
plt.ylabel('TEMPERATURE')
plt.title('Forest Fires Scatter Plot')
corr = data['FFMC'].corr(data['temp'])
plt.plot(data['FFMC'], corr * data['FFMC'], color='red')
plt.show()

# %%
data_with_constant = sm.add_constant(data[['FFMC', 'temp']])
model = sm.OLS(data['temp'], data_with_constant)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   temp   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 4.965e+32
# Date:                Mon, 05 Jun 2023   Prob (F-statistic):               0.00
# Time:                        11:08:30   Log-Likelihood:                 16384.
# No. Observations:                 517   AIC:                        -3.276e+04
# Df Residuals:                     514   BIC:                        -3.275e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -3.582e-14   3.13e-15    -11.442      0.000    -4.2e-14   -2.97e-14
# FFMC        2.875e-16    3.7e-17      7.768      0.000    2.15e-16     3.6e-16
# temp           1.0000   3.52e-17   2.84e+16      0.000       1.000       1.000
# ==============================================================================
# Omnibus:                      100.294   Durbin-Watson:                   0.977
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              528.845
# Skew:                           0.729   Prob(JB):                    1.45e-115
# Kurtosis:                       7.735   Cond. No.                     1.58e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.58e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
